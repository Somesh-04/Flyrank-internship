# %% [markdown]
# <a href="https://colab.research.google.com/github/Somesh-04/Flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Somesh-04/Flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# For my lane, I'm focusing on CTR / Engagement Opportunity Scoring — basically finding pages that are ranking well in search but not getting the clicks they should be getting for that position.
#
# I picked this direction because the dataset already gives me everything I need for it: CTR, impressions, average position, and engagement metrics. Also, when I did my Week 1 analysis, I noticed average position and CTR only had a weak negative relationship — which told me position alone doesn't explain click behavior well. That gap is exactly what I want to dig into: pages that should be getting more clicks based on where they rank, but aren't, so I can flag them for review.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The core question I'm trying to answer is: which visible pages are underperforming on CTR relative to their search position, and which of those should a reviewer look at first?
#
# At the end of the day, this comes down to a prioritization decision — figuring out which pages actually deserve a reviewer's limited time and attention. Once a page is flagged, there are a few possible next steps: rewriting the title or metadata, checking whether the page actually matches search intent, improving how the snippet is structured, improving on-page engagement, or simply monitoring it a bit longer if it's not clearly an issue yet.
#
# The stakes here matter too — if I recommend the wrong pages, reviewers end up spending time on something that doesn't actually have real upside, while pages with genuine opportunity go unnoticed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
import os
import subprocess
import pandas as pd

REPO_URL = "https://github.com/Somesh-04/Flyrank-internship"
REPO_DIR = "/content/Flyrank-internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

csv_path = os.path.join(REPO_DIR, "data", "raw", "content_refresh_anonymized.csv")

df = pd.read_csv(csv_path)

print("Rows:", len(df))
print("Mean CTR:", round(df["ctr"].mean(), 3))
print("Mean average position:", round(df["avg_position"].mean(), 2))
# Out:
# Rows: 30000
# Mean CTR: 0.511
# Mean average position: 16.34

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# What I can do here is point out patterns and directional relationships in the data — for example, "pages like this tend to underperform on CTR at this position" — and use that to help prioritize what a reviewer should look at first.
#
# What I can't do is claim causation. I can't say low CTR is because of a specific factor, I can't guarantee that changing something on a page will actually improve its performance, and I definitely can't claim I've uncovered some piece of Google's ranking algorithm. This is decision-support, not proof — the output is meant to guide where a human reviewer spends their time, not replace their judgment.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
